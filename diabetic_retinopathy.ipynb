# %% [markdown]
# <a href="https://colab.research.google.com/github/guna1743/Dropdownmenu/blob/main/diabetic_retinopathy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



df = pd.read_csv('/content/dataset.csv')
df.head()
# Out:
#    Name     Sex   Age   BMI DM type  DM duration    FBS  A1C    LDL   HDL  \
# 0   1.0    Male  65.0  25.0      II         20.0  129.0  7.1  100.0  40.0
# 1   2.0    Male  42.0  27.0      II          3.0  210.0  8.9  125.0  38.0
# 2   3.0  Female  31.0  21.0       I         11.0  164.0  7.7  147.0  35.0
# 3   4.0    Male  70.0  32.0      II         29.0  208.0  9.3  119.0  36.0
# 4   5.0  Female  54.0  34.0      II          6.0  183.0  9.8  196.0  32.0
#
#       TG  Sys BP  Dias BP DM treat    Statin  Dose ( Í2 if BID) Ret-pathy
# 0  200.0   130.0     80.0     Oral       Ator                40      Yes
# 1  151.0   140.0     90.0     Oral       Ator                20        No
# 2  217.0   145.0     80.0      Ins  No statin                No      Yes
# 3  168.0   160.0    100.0      Ins       Ator                80      Yes
# 4  197.0   155.0     95.0     Oral       Ator                40        No

# %%
df.shape
# Out:
# (213, 17)

# %%
df.keys()
# Out:
# Index(['Name', 'Sex', 'Age', 'BMI', 'DM type', 'DM duration', 'FBS', 'A1C',
#        'LDL', 'HDL', 'TG', 'Sys BP', 'Dias BP', 'DM treat', 'Statin ',
#        'Dose ( Í2 if BID)', 'Ret-pathy'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               133 non-null    float64
#  1   Sex                133 non-null    object
#  2   Age                133 non-null    float64
#  3   BMI                133 non-null    float64
#  4   DM type            133 non-null    object
#  5   DM duration        133 non-null    float64
#  6   FBS                133 non-null    float64
#  7   A1C                133 non-null    float64
#  8   LDL                133 non-null    float64
#  9   HDL                133 non-null    float64
#  10  TG                 133 non-null    float64
#  11  Sys BP             133 non-null    float64
#  12  Dias BP            133 non-null    float64
#  13  DM treat           133 non-null    object
#  14  Statin             133 non-null    object
# ...

# %%
df.describe()
# Out:
#             Name         Age         BMI  DM duration         FBS         A1C  \
# count  133.00000  133.000000  133.000000   133.000000  133.000000  133.000000
# mean    67.00000   54.345865   29.133835    10.279699  208.902256   10.607970
# std     38.53786   12.542078    4.973671     6.852690   68.766829   10.858141
# min      1.00000   16.000000   18.000000     0.000000   80.000000    6.500000
# 25%     34.00000   45.000000   27.000000     4.000000  159.000000    8.000000
# 50%     67.00000   55.000000   30.000000    10.000000  200.000000    9.400000
# 75%    100.00000   64.000000   33.000000    15.000000  257.000000   11.100000
# max    133.00000   79.000000   41.000000    30.000000  510.000000  133.000000
#
#               LDL         HDL          TG      Sys BP     Dias BP
# count  133.000000  133.000000  133.000000  133.000000  133.000000
# mean   134.052632   37.082707  212.030075  144.060150   90.330827
# std     44.411355    7.047507   99.071671   18.891139   13.820122
# ...

# %%
df.isna().sum()
# Out:
# Name                 80
# Sex                  80
# Age                  80
# BMI                  80
# DM type              80
# DM duration          80
# FBS                  80
# A1C                  80
# LDL                  80
# HDL                  80
# TG                   80
# Sys BP               80
# Dias BP              80
# DM treat             80
# Statin               80
# Dose ( Í2 if BID)    80
# Ret-pathy            80
# dtype: int64

# %%
df.dropna(axis = 0, inplace = True) 
print(df.shape)
# Out:
# (133, 17)

# %%
df['Ret-pathy'].value_counts()
# Out:
# No      91
# Yes     42
# Name: Ret-pathy, dtype: int64

# %%
plt.figure(figsize = (14, 10)) 
sns.heatmap(df.corr(), cmap='Purples',annot=True, linecolor='Green', linewidths=1.0)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.catplot(data=df, kind='count', x='Sex',hue='DM type')
plt.show()

# %%
sns.catplot(data=df, kind='count', x='Ret-pathy', col='Sex',row='DM type', palette='Blues')
plt.show()

# %%
X = df.iloc[:,0:7]
y = df.iloc[:,16:17]
X.head()
# Out:
#    Name     Sex   Age   BMI DM type  DM duration    FBS
# 0   1.0    Male  65.0  25.0      II         20.0  129.0
# 1   2.0    Male  42.0  27.0      II          3.0  210.0
# 2   3.0  Female  31.0  21.0       I         11.0  164.0
# 3   4.0    Male  70.0  32.0      II         29.0  208.0
# 4   5.0  Female  54.0  34.0      II          6.0  183.0

# %%
y.head()
# Out:
#   Ret-pathy
# 0      Yes
# 1        No
# 2      Yes
# 3      Yes
# 4        No

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=21)

logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

score = logreg.score(X_test, y_test)
print("Prediction score is:",score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-7ddd77ddf6f7> in <module>
#       2 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=21)
#       3
# ----> 4 logreg.fit(X_train, y_train)
#       5
#       6 y_pred = logreg.predict(X_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...

# %%
from sklearn.metrics import confusion_matrix, classification_report 
cm = confusion_matrix(y_test, y_pred) 
print("Confusion Matrix is:\n",cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-fa3af8e23fd8> in <module>
#       1 from sklearn.metrics import confusion_matrix, classification_report
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 print("Confusion Matrix is:\n",cm)
#
# NameError: name 'y_pred' is not defined

# %%
print("Classification Report is:\n\n",classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-d340da238439> in <module>
# ----> 1 print("Classification Report is:\n\n",classification_report(y_test,y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (10, 6)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-9ef2570f42bf> in <module>
# ----> 1 conf_matrix = pd.DataFrame(data = cm,
#       2                            columns = ['Predicted:0', 'Predicted:1'],
#       3                            index =['Actual:0', 'Actual:1'])
#       4 plt.figure(figsize = (10, 6))
#       5 sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens", linecolor="Blue", linewidths=1.5)
#
# NameError: name 'cm' is not defined
